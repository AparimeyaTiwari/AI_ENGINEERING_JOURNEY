# %% [markdown]
# # 🔥 Why Do We Need PyTorch?
#
# ### Notes from DeepLearning.AI - PyTorch Fundamentals
#
# ---
#
# ## 💡 The Beautiful Simplicity
#
# ### Regular Code:
# ```python
# result = a + b
# ```
#
# ### PyTorch Code:
# ```python
# a = torch.tensor(2.0)
# b = torch.tensor(3.0)
# result = a + b
# print(result)
# ```
#
# ### ✨ Voila!
# - Looks like **normal Python code**
# - We can learn deep learning with **simple Python**, my buddies! 🎉
#
# ---
#
# ## 🤔 Traditional Programming vs ML vs Deep Learning
#
# ### 🔧 Traditional Programming:
# 1. Give **input**
# 2. Apply **rule**
# 3. Get **output**
#
# ### 🤖 Machine Learning:
# 1. Give **input**
# 2. Give **output**
# 3. Train our **model** (it learns the rules!)
#
# ### 🧠 Deep Learning:
# - Complex maths in the background
# - Example: Customer history → Product recommendations
# - **TOO MUCH MATH THOUGH** 😱
#
# ---
#
# ## 😤 The Problem with Initial Frameworks
#
# ### WOMP WOMP 💀
#
# Early frameworks had major issues:
#
# ❌ Build entire assembly line upfront
# ❌ Cannot add operations after performed
# ❌ Fixed input size only
# ❌ Not like normal Python
#
# ### 🚨 WE NEED A DIFFERENT FRAMEWORK!
#
# ---
#
# ## 🎯 PyTorch's Core Principle
#
# > ### *"Deep learning should feel like Python"*
#
# ### ✅ What This Means:
# - **Dumbed down version** of things
# - Can identify **errors like Python**
# - **Powerful tool** + **powerful community**
#
# ### 🏆 Result:
# ## → **GO-TO CHOICE** for deep learning! 🚀
#
# ---
#
# ## 🎓 Summary
#
# PyTorch wins because:
# 1. 🐍 Feels like **regular Python**
# 2. 🔍 **Easy debugging**
# 3. 🌍 **Massive community** support
# 4. 💪 **Powerful** yet **simple**
#
# *That's why everyone's using it!* ✨

# %% [markdown]
# # 🧠 Revision of Neural Networks
#
# ### Notes from DeepLearning.AI - PyTorch Fundamentals
#
# ---
#
# ## 🎯 The Problem Setup
#
# **Scenario:** You deliver food products
# **Goal:** Under 30 minutes only, man! ⏰
# **Question:** Given a 7-mile location, should you deliver or not??
#
# ---
#
# ## 🔬 Neural Networks Can Be Used!
#
# ### Starting with a Single Neuron
#
# **Neurons → single mathematical unit**
#
# ---
#
# ## 📊 The Steps
#
# ### i) Input
# We pass in **distance** to the neuron
#
# ### ii) Neuron Output
# ```
# Output = Weight × distance + bias
# ```
#
# ### iii) Compare with Actual Data
# - Compare result with the actual data or graph
# - Here we assumed that the relationship between distance and time is **linear** (linear graph can be drawn)
#
# ### iv) Gradient Descent via Calculus
# - Calculus to calculate **gradient of descent** and how close we are
# - Kind of like: change value of **weight** and **bias** in model and see if we go close to result or not
#
# ---
#
# ## 🏗️ Layers Explained
#
# ### a) Input Layer 🚪
# We simply take in the **input features**
#
# ### b) Hidden Layers 🔮
# Layer where the **computation is performed**:
# - Linear regression
# - Activation function
#
# ### c) Output Layer 📤
# To store the **prediction**
#
# ---
#
# ## 💡 Important NOTE:
#
# ### You might think calculations become very complex for a lot of data → uh....no
#
# **Why?**
#
# We are still doing the **same linear calculation!**
#
# ### Example:
# If we consider **weather** and **time of day**:
#
# ```
# Output of a neuron = W1×distance + W2×weather + W3×time_of_day + bias
# ```
#
# ### ✨ Voila! Still a linear equation, man! 🎉
